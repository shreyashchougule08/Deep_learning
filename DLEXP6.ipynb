# %%
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.datasets import imdb
from tensorflow.keras.preprocessing.sequence import pad_sequences
import matplotlib.pyplot as plt

# %%
# Load dataset (top 10,000 words)
vocab_size = 10000
max_len = 200

(x_train, y_train), (x_test, y_test) = imdb.load_data(num_words=vocab_size)

# Pad sequences (make equal length)
x_train = pad_sequences(x_train, maxlen=max_len)
x_test = pad_sequences(x_test, maxlen=max_len)

print(x_train.shape)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/imdb.npz
# 17464789/17464789 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# (25000, 200)

# %%
def build_rnn():
    model = models.Sequential([
        layers.Embedding(vocab_size, 64, input_length=max_len),
        layers.SimpleRNN(64),
        layers.Dense(1, activation='sigmoid')
    ])

    model.compile(optimizer='adam',
                  loss='binary_crossentropy',
                  metrics=['accuracy'])
    return model

rnn_model = build_rnn()
history_rnn = rnn_model.fit(x_train, y_train,
                            epochs=5,
                            validation_data=(x_test, y_test))
# Out:
# Epoch 1/5
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/embedding.py:100: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 53s 65ms/step - accuracy: 0.6590 - loss: 0.6123 - val_accuracy: 0.6640 - val_loss: 0.5992
# Epoch 2/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 51s 66ms/step - accuracy: 0.6998 - loss: 0.5761 - val_accuracy: 0.6596 - val_loss: 0.6002
# Epoch 3/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 50s 64ms/step - accuracy: 0.7905 - loss: 0.4472 - val_accuracy: 0.7483 - val_loss: 0.5540
# Epoch 4/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 82s 64ms/step - accuracy: 0.8099 - loss: 0.4226 - val_accuracy: 0.7590 - val_loss: 0.5631
# Epoch 5/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 82s 64ms/step - accuracy: 0.8505 - loss: 0.3494 - val_accuracy: 0.7395 - val_loss: 0.5856

# %%
def build_lstm():
    model = models.Sequential([
        layers.Embedding(vocab_size, 64, input_length=max_len),
        layers.LSTM(64),
        layers.Dense(1, activation='sigmoid')
    ])

    model.compile(optimizer='adam',
                  loss='binary_crossentropy',
                  metrics=['accuracy'])
    return model

lstm_model = build_lstm()
history_lstm = lstm_model.fit(x_train, y_train,
                              epochs=5,
                              validation_data=(x_test, y_test))
# Out:
# Epoch 1/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 109s 136ms/step - accuracy: 0.8063 - loss: 0.4208 - val_accuracy: 0.8668 - val_loss: 0.3218
# Epoch 2/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 141s 134ms/step - accuracy: 0.8961 - loss: 0.2585 - val_accuracy: 0.8688 - val_loss: 0.3114
# Epoch 3/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 106s 136ms/step - accuracy: 0.9253 - loss: 0.1926 - val_accuracy: 0.8721 - val_loss: 0.3487
# Epoch 4/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 142s 136ms/step - accuracy: 0.9500 - loss: 0.1402 - val_accuracy: 0.8768 - val_loss: 0.3594
# Epoch 5/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 159s 158ms/step - accuracy: 0.9630 - loss: 0.1044 - val_accuracy: 0.8664 - val_loss: 0.3936

# %%
def build_gru():
    model = models.Sequential([
        layers.Embedding(vocab_size, 64, input_length=max_len),
        layers.GRU(64),
        layers.Dense(1, activation='sigmoid')
    ])

    model.compile(optimizer='adam',
                  loss='binary_crossentropy',
                  metrics=['accuracy'])
    return model

gru_model = build_gru()
history_gru = gru_model.fit(x_train, y_train,
                            epochs=5,
                            validation_data=(x_test, y_test))
# Out:
# Epoch 1/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - accuracy: 0.7136 - loss: 0.5237
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_10038/3524685924.py in <cell line: 0>()
#      12
#      13 gru_model = build_gru()
# ---> 14 history_gru = gru_model.fit(x_train, y_train,
#      15                             epochs=5,
#      16                             validation_data=(x_test, y_test))
#
# /usr/local/lib/python3.12/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#     115         filtered_tb = None
#     116         try:
# --> 117             return fn(*args, **kwargs)
#     118         except Exception as e:
#     119             filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.12/dist-packages/keras/src/backend/tensorflow/trainer.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq)
#     432                 )
#     433                 val_logs = {
# --> 434                     f"val_{name}": val for name, val in val_logs.items()
#     435                 }
#     436                 epoch_logs.update(val_logs)
#
# KeyboardInterrupt:

# %%
plt.plot(history_rnn.history['val_accuracy'], label='RNN')
plt.plot(history_lstm.history['val_accuracy'], label='LSTM')
plt.plot(history_gru.history['val_accuracy'], label='GRU')

plt.xlabel('Epochs')
plt.ylabel('Validation Accuracy')
plt.legend()
plt.show()
